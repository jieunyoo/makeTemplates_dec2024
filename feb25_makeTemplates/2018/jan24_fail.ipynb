# %%
import argparse
import glob
import json
import logging
import os
import pickle as pkl
import warnings
import hist as hist2
import numpy as np
import pandas as pd
import pyarrow
import yaml
import math

from utils import get_common_sample_name, get_finetuned_score, get_xsecweight

from systematicsFail import get_systematic_dict, sigs

logging.basicConfig(level=logging.INFO)
warnings.filterwarnings("ignore", message="Found duplicate branch ")
pd.set_option("mode.chained_assignment", None)


#note import jieun2.py for "fail"
from jieun2R import fix_neg_yields, get_templates, mass_binning  #importing get_templates automatically it seems imports the other functions



CATEGORY = 'fail'

# %%
years = ['2018']

outdir = 'templates'

channels = 'mu','ele'
#channels = ['mu']


with open("simpleFail.yaml", "r") as stream:
    config = yaml.safe_load(stream)

if len(years) == 4:
    save_as = "Run2"
else:
    save_as = "_".join(years)

if len(channels) == 1:
    save_as += f"_{channels[0]}_"

os.system(f"mkdir -p {outdir}")

hists = get_templates( years, channels, config["samples"], config["samples_dir"], config["regions_sel"], config["model_path"],)

fix_neg_yields(hists)

#with open(f"{outdir}/hists_templates_{save_as}.pkl", "wb") as fp:
with open(f"{outdir}/hists_templates_{save_as}_fail.pkl", "wb") as fp:
    print('hists', hists)
    pkl.dump(hists, fp)
# Out:
# INFO:root:Processing year 2018 and mu channel
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 871 events
# INFO:root:Applying SR1 selection on 864 events
# INFO:root:Will fill the histograms with the remaining 18 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-100To250 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 27737 events
# INFO:root:Applying SR1 selection on 27450 events
# INFO:root:Will fill the histograms with the remaining 758 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-250To400 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 124445 events
# INFO:root:Applying SR1 selection on 122654 events
# INFO:root:Will fill the histograms with the remaining 2064 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# ...

# %%
obj = pd.read_pickle(r'/home/jieun201/boostedhiggs_may27/combine_nov26/2018/templates/hists_templates_2018_fail.pkl')

# %%
obj
# Out:
# Hist(
#   StrCategory(['DYJets', 'EWKvjets', 'ggF', 'ZH', 'WH', 'SingleTop', 'TTbar', 'VBF', 'WJetsLNu', 'Diboson', 'ttH'], growth=True, name='Sample'),
# ...

# %%
sample2 = obj[{"Region": "SR1", "Sample": "WJetsLNu", "Systematic": "fail_nominal"}]
sample2
# Out:
# Hist(Variable([40, 70, 110, 140, 180], name='mass_observable', label='V reconstructed mass [GeV]'), storage=Weight()) # Sum: WeightedSum(value=3656.9, variance=1035.83) (WeightedSum(value=3844.43, variance=1086.21) with flow)

# %%
sample2 = obj[{"Region": "SR1", "Sample": "WJetsLNu", "Systematic": "fail_weight_PSFSR_WJetsLNu_up"}]
sample2
# Out:
# Hist(Variable([40, 70, 110, 140, 180], name='mass_observable', label='V reconstructed mass [GeV]'), storage=Weight()) # Sum: WeightedSum(value=3619.41, variance=1208.37) (WeightedSum(value=3808.99, variance=1267.15) with flow)

# %%
#sample2 = obj[{"Region": "SR1", "Sample": "ZH", "Systematic": "pass_JMS_2017_down"}]
sample2 = obj[{"Region": "SR1", "Sample": "WJetsLNu", "Systematic": "fail_weight_PSFSR_WJetsLNu_down"}]

sample2
# Out:
# Hist(Variable([40, 70, 110, 140, 180], name='mass_observable', label='V reconstructed mass [GeV]'), storage=Weight()) # Sum: WeightedSum(value=3653.59, variance=1848.95) (WeightedSum(value=3841.3, variance=1936.77) with flow)

# %%
sample2 = obj[{"Region": "SR1", "Sample": "ZH", "Systematic": "fail_nominal"}]
sample2
# Out:
# Hist(Variable([40, 70, 110, 140, 180], name='mass_observable', label='V reconstructed mass [GeV]'), storage=Weight()) # Sum: WeightedSum(value=2.58419, variance=0.00217984) (WeightedSum(value=2.61358, variance=0.00220551) with flow)

# %%
#sample2 = obj[{"Region": "SR1", "Sample": "ZH", "Systematic": "pass_JMS_2017_up"}]
sample2 = obj[{"Region": "SR1", "Sample": "ZH", "Systematic": "fail_UES_up"}]



sample2
# Out:
# Hist(Variable([40, 70, 110, 140, 180], name='mass_observable', label='V reconstructed mass [GeV]'), storage=Weight()) # Sum: WeightedSum(value=2.59252, variance=0.00219104) (WeightedSum(value=2.62281, variance=0.00221743) with flow)

# %%
sample2 = obj[{"Region": "SR1", "Sample": "ZH", "Systematic": "fail_nominal"}]
sample2
# Out:
# Hist(Variable([40, 70, 110, 140, 180], name='mass_observable', label='V reconstructed mass [GeV]'), storage=Weight()) # Sum: WeightedSum(value=2.58419, variance=0.00217984) (WeightedSum(value=2.61358, variance=0.00220551) with flow)
