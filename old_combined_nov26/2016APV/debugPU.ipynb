# %%
import uproot
import pandas as pd

import boost_histogram as bh
#outFile = uproot.recreate(f"{2018}.root")

# %%
file1= uproot.open("/home/jieun201/boostedhiggs_may27/combine_nov26/2016APV/2016APV.root")
file1
# Out:
# <ReadOnlyDirectory '/' at 0x7f3a204e4430>

# %%
h = file1['SingleTop_pass_weight_PSFSR_SingleTop_up;1']
h.to_hist().plot(label='up')
import matplotlib.pyplot as plt
h2 = file1['SingleTop_pass_weight_PSFSR_SingleTop_down;1']
h2.to_hist().plot(label='down')
#h = file1['WJetsLNu_pass_weight_btagSFlight_up']
#h.to_hist().plot()
h3 = file1['SingleTop_pass_nominal']
h3.to_hist().plot(label='nominal')
plt.legend()
plt.title('SingleTop PSFSR, 2016APV')
# Out:
# Text(0.5, 1.0, 'SingleTop PSFSR, 2016APV')

# %%
h = file1['WJetsLNu_pass_weight_pileup_up']
h.to_hist().plot(label='up')
import matplotlib.pyplot as plt
h2 = file1['WJetsLNu_pass_weight_pileup_down']
h2.to_hist().plot(label='down')
#h = file1['WJetsLNu_pass_weight_btagSFlight_up']
#h.to_hist().plot()
h3 = file1['WJetsLNu_pass_nominal']
h3.to_hist().plot(label='nominal')
plt.legend()
plt.title('WJetsLNu pileup 2016APV')
# Out:
# Text(0.5, 1.0, 'WJetsLNu pileup 2016APV')

# %%
h = file1['TTbar_pass_weight_pileup_up']
h.to_hist().plot(label='up')
import matplotlib.pyplot as plt
h2 = file1['TTbar_pass_weight_pileup_down']
h2.to_hist().plot(label='down')
#h = file1['WJetsLNu_pass_weight_btagSFlight_up']
#h.to_hist().plot()
h3 = file1['TTbar_pass_nominal']
h3.to_hist().plot(label='nominal')
plt.legend()
plt.title('TTbar pileup 2016APV')
# Out:
# Text(0.5, 1.0, 'TTbar pileup 2016APV')

# %%
h = file1['WH_pass_weight_pileup_up']
h.to_hist().plot(label='up')
import matplotlib.pyplot as plt
h2 = file1['WH_pass_weight_pileup_down']
h2.to_hist().plot(label='down')
#h = file1['WJetsLNu_pass_weight_btagSFlight_up']
#h.to_hist().plot()
h3 = file1['WH_pass_nominal']
h3.to_hist().plot(label='nominal')
plt.legend()
plt.title('WH pileup 2016APV')
# Out:
# Text(0.5, 1.0, 'WH pileup 2016APV')

# %%
h = file1['ZH_pass_weight_pileup_up']
h.to_hist().plot(label='up')
import matplotlib.pyplot as plt
h2 = file1['ZH_pass_weight_pileup_down']
h2.to_hist().plot(label='down')
#h = file1['WJetsLNu_pass_weight_btagSFlight_up']
#h.to_hist().plot()
h3 = file1['ZH_pass_nominal']
h3.to_hist().plot(label='nominal')
plt.legend()
plt.title('ZH pileup 2016APV')
# Out:
# Text(0.5, 1.0, 'ZH pileup 2016APV')

# %%
h = file1['DYJets_pass_weight_pileup_up']
h.to_hist().plot(label='up')
import matplotlib.pyplot as plt
h2 = file1['DYJets_pass_weight_pileup_down']
h2.to_hist().plot(label='down')
#h = file1['WJetsLNu_pass_weight_btagSFlight_up']
#h.to_hist().plot()
h3 = file1['DYJets_pass_nominal']
h3.to_hist().plot(label='nominal')
plt.legend()
plt.title('DYJets pileup 2016APV')
# Out:
# Text(0.5, 1.0, 'DYJets pileup 2016APV')
