# %%
import uproot
import pandas as pd

import boost_histogram as bh
#outFile = uproot.recreate(f"{2018}.root")

# %%
file1= uproot.open("/home/jieun201/boostedhiggs_may27/combine_nov26/2018/2018.root")
file1

#pass_weight_PSFSR_SingleTop_up
# Out:
# <ReadOnlyDirectory '/' at 0x7f06b9045d20>

# %%
h3 = file1['SingleTop_pass_nominal']
h3.to_hist().plot(label='nominal')
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f06b7455990>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
h = file1['SingleTop_pass_weight_PSFSR_SingleTop_up;1']
h.to_hist().plot(label='up')
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f06b9d21bd0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
h = file1['SingleTop_pass_weight_PSFSR_SingleTop_up;1']
h.to_hist().plot(label='up')
import matplotlib.pyplot as plt
h2 = file1['SingleTop_pass_weight_PSFSR_SingleTop_down;1']
h2.to_hist().plot(label='down')
#h = file1['WJetsLNu_pass_weight_btagSFlight_up']
#h.to_hist().plot()
h3 = file1['SingleTop_pass_nominal']
h3.to_hist().plot(label='nominal')
plt.legend()
plt.title('SingleTop PSFSR, 2018')
# Out:
# Text(0.5, 1.0, 'SingleTop PSFSR, 2018')

# %%
h = file1['SingleTop_pass_weight_PSFSR_up']
h.to_hist().plot(label='up')
import matplotlib.pyplot as plt
h2 = file1['SingleTop_pass_weight_PSFSR_down']
h2.to_hist().plot(label='down')
#h = file1['WJetsLNu_pass_weight_btagSFlight_up']
#h.to_hist().plot()
h3 = file1['SingleTop_pass_nominal']
h3.to_hist().plot(label='nominal')
plt.legend()
plt.title('SingleTop PSFSR 2018')
# Out:
# ---------------------------------------------------------------------------
# KeyInFileError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 h = file1['pass_weight_PSFSR_SingleTop_up']
#       2 h.to_hist().plot(label='up')
#       3 import matplotlib.pyplot as plt
#
# File ~/.local/lib/python3.10/site-packages/uproot/reading.py:2107, in ReadOnlyDirectory.__getitem__(self, where)
#    2104     return step
#    2106 else:
# -> 2107     return self.key(where).get()
#
# File ~/.local/lib/python3.10/site-packages/uproot/reading.py:2057, in ReadOnlyDirectory.key(self, where)
#    2055     return last
#    2056 elif cycle is None:
# -> 2057     raise uproot.KeyInFileError(
#    2058         item, cycle="any", keys=self.keys(), file_path=self._file.file_path
#    2059     )
#    2060 else:
#    2061     raise uproot.KeyInFileError(
#    2062         item, cycle=cycle, keys=self.keys(), file_path=self._file.file_path
#    2063     )
#
# KeyInFileError: not found: 'pass_weight_PSFSR_SingleTop_up' (with any cycle number)
#
#     Available keys: (none!)
#
# in file /home/jieun201/boostedhiggs_may27/combine/2018/2018.root

# %%
h = file1['TTbar_pass_weight_pileup_up']
h.to_hist().plot(label='up')
import matplotlib.pyplot as plt
h2 = file1['TTbar_pass_weight_pileup_down']
h2.to_hist().plot(label='down')
#h = file1['WJetsLNu_pass_weight_btagSFlight_up']
#h.to_hist().plot()
h3 = file1['TTbar_pass_nominal']
h3.to_hist().plot(label='nominal')
plt.legend()
plt.title('TTbar pileup 2018')
# Out:
# Text(0.5, 1.0, 'TTbar pileup 2018')

# %%
h = file1['WH_pass_weight_pileup_up']
h.to_hist().plot(label='up')
import matplotlib.pyplot as plt
h2 = file1['WH_pass_weight_pileup_down']
h2.to_hist().plot(label='down')
#h = file1['WJetsLNu_pass_weight_btagSFlight_up']
#h.to_hist().plot()
h3 = file1['WH_pass_nominal']
h3.to_hist().plot(label='nominal')
plt.legend()
plt.title('WH pileup 2018')
# Out:
# Text(0.5, 1.0, 'WH pileup 2018')

# %%
h = file1['ZH_pass_weight_pileup_up']
h.to_hist().plot(label='up')
import matplotlib.pyplot as plt
h2 = file1['ZH_pass_weight_pileup_down']
h2.to_hist().plot(label='down')
#h = file1['WJetsLNu_pass_weight_btagSFlight_up']
#h.to_hist().plot()
h3 = file1['ZH_pass_nominal']
h3.to_hist().plot(label='nominal')
plt.legend()
plt.title('ZH pileup 2018')
# Out:
# Text(0.5, 1.0, 'ZH pileup 2018')

# %%
h = file1['DYJets_pass_weight_pileup_up']
h.to_hist().plot(label='up')
import matplotlib.pyplot as plt
h2 = file1['DYJets_pass_weight_pileup_down']
h2.to_hist().plot(label='down')
#h = file1['WJetsLNu_pass_weight_btagSFlight_up']
#h.to_hist().plot()
h3 = file1['DYJets_pass_nominal']
h3.to_hist().plot(label='nominal')
plt.legend()
plt.title('DYJets pileup 2018')
# Out:
# Text(0.5, 1.0, 'DYJets pileup 2018')
