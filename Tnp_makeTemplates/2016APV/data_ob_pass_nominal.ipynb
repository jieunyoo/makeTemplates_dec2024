# %%
import glob
import os
import json
import pickle  
import yaml
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None
import pyarrow.parquet as pq
import hist as hist2
import matplotlib.pyplot as plt
import mplhep as hep
plt.style.use(hep.style.CMS)
import utils_farouk2 as utils
plt.rcParams.update({"font.size": 20})
import pickle as pkl
import uproot
import pandas as pd
import boost_histogram as bh
from utils_farouk2 import plot_hists

# %%
year = "2016APV"
samples_dir="/uscms/home/jieun201/nobackup/YOURWORKINGAREA/oct4_wjet_2016APV/oct4_2016APV_2016APV"

samples = [  
           "Data",
          ]
samples_to_plot = samples
channels = ["ele", "mu"]

# %%
events_dict = utils.event_skimmer_noInference(year, channels, samples_dir, samples, "all", add_qcd_score=False, add_top_score=False, add_inclusive_score=False)
h = hist2.Hist(hist2.axis.Regular(15, 40, 180, name="var", label=r"jet softdrop mass [GeV]", overflow=True))

for sample in samples_to_plot:
    print('sample', sample)
        
    for ch in channels:
      
        df = events_dict[ch][sample] 
        df = df[       (df["lep_fj_dr"] > 1.0 )   & (df["numberBJets_Medium_OutsideWFatJet"] > 0)     & (df['met_pt']> 30) 
        &   (df["numberLeptons"] == 1) 
        & (df["fj_pt"] > 250) & (df["fj_pt"] < 2000) 
         & (df["VScore_WJet"] > 0.9)  
        ]  
        h.fill( var=df["fj_msoftdrop"],weight=df["event_weight"] )


h_uproot = uproot.to_writable(h)
file = uproot.recreate(f"/home/jieun201/may18/boostedhiggs/python/oct3_2016APV_MC/data_obs_pass_nominal.root")
file['data_obs_pass_nominal']=h_uproot
#*****
h
# Out:
# luminosity 19492.72
# ATTENTION: DYJetsToLL_LHEFilterPtZ-0To50 will be skipped
# ATTENTION: DYJetsToLL_LHEFilterPtZ-100To250 will be skipped
# ATTENTION: DYJetsToLL_LHEFilterPtZ-250To400 will be skipped
# ATTENTION: DYJetsToLL_LHEFilterPtZ-400To650 will be skipped
# ATTENTION: DYJetsToLL_LHEFilterPtZ-50To100 will be skipped
# ATTENTION: DYJetsToLL_LHEFilterPtZ-650ToInf will be skipped
# ATTENTION: EWKWminus_WToLNu will be skipped
# ATTENTION: EWKWminus_WToQQ will be skipped
# ATTENTION: EWKWplus_WToLNu will be skipped
# ATTENTION: EWKWplus_WToQQ will be skipped
# ATTENTION: EWKZ_ZToLL will be skipped
# ATTENTION: EWKZ_ZToNuNu will be skipped
# ATTENTION: EWKZ_ZToQQ will be skipped
# ATTENTION: QCD_Pt_1000to1400 will be skipped
# ATTENTION: QCD_Pt_1400to1800 will be skipped
# ATTENTION: QCD_Pt_170to300 will be skipped
# ATTENTION: QCD_Pt_1800to2400 will be skipped
# ATTENTION: QCD_Pt_2400to3200 will be skipped
# ATTENTION: QCD_Pt_300to470 will be skipped
# ATTENTION: QCD_Pt_3200toInf will be skipped
# ATTENTION: QCD_Pt_470to600 will be skipped
# ATTENTION: QCD_Pt_600to800 will be skipped
# ATTENTION: QCD_Pt_800to1000 will be skipped
# ATTENTION: ST_s-channel_4f_hadronicDecays will be skipped
# ATTENTION: ST_s-channel_4f_leptonDecays will be skipped
# ATTENTION: ST_t-channel_antitop_4f_InclusiveDecays will be skipped
# ATTENTION: ST_t-channel_top_4f_InclusiveDecays will be skipped
# ATTENTION: ST_tW_antitop_5f_inclusiveDecays will be skipped
# ATTENTION: ST_tW_top_5f_inclusiveDecays will be skipped
# ATTENTION: TTTo2L2Nu will be skipped
# ATTENTION: TTToHadronic will be skipped
# ATTENTION: TTToSemiLeptonic will be skipped
# ATTENTION: WJetsToLNu_HT-100To200 will be skipped
# ATTENTION: WJetsToLNu_HT-1200To2500 will be skipped
# ATTENTION: WJetsToLNu_HT-200To400 will be skipped
# ATTENTION: WJetsToLNu_HT-2500ToInf will be skipped
# ATTENTION: WJetsToLNu_HT-400To600 will be skipped
# ATTENTION: WJetsToLNu_HT-600To800 will be skipped
# ATTENTION: WJetsToLNu_HT-800To1200 will be skipped
# ATTENTION: WJetsToQQ_HT-200to400 will be skipped
# ATTENTION: WJetsToQQ_HT-400to600 will be skipped
# ATTENTION: WJetsToQQ_HT-600to800 will be skipped
# ATTENTION: WJetsToQQ_HT-800toInf will be skipped
# ATTENTION: WW will be skipped
# ATTENTION: WZ will be skipped
# ATTENTION: ZJetsToQQ_HT-200to400 will be skipped
# ATTENTION: ZJetsToQQ_HT-400to600 will be skipped
# ATTENTION: ZJetsToQQ_HT-600to800 will be skipped
# ATTENTION: ZJetsToQQ_HT-800toInf will be skipped
# ATTENTION: ZZ will be skipped
# is data
# is data
# is data
# is data
# is data
# is data
# is data
# is data
# is data
# is data
# luminosity 19436.16
# ATTENTION: DYJetsToLL_LHEFilterPtZ-0To50 will be skipped
# ATTENTION: DYJetsToLL_LHEFilterPtZ-100To250 will be skipped
# ATTENTION: DYJetsToLL_LHEFilterPtZ-250To400 will be skipped
# ATTENTION: DYJetsToLL_LHEFilterPtZ-400To650 will be skipped
# ATTENTION: DYJetsToLL_LHEFilterPtZ-50To100 will be skipped
# ATTENTION: DYJetsToLL_LHEFilterPtZ-650ToInf will be skipped
# ATTENTION: EWKWminus_WToLNu will be skipped
# ATTENTION: EWKWminus_WToQQ will be skipped
# ATTENTION: EWKWplus_WToLNu will be skipped
# ATTENTION: EWKWplus_WToQQ will be skipped
# ATTENTION: EWKZ_ZToLL will be skipped
# ATTENTION: EWKZ_ZToNuNu will be skipped
# ATTENTION: EWKZ_ZToQQ will be skipped
# ATTENTION: QCD_Pt_1000to1400 will be skipped
# ATTENTION: QCD_Pt_1400to1800 will be skipped
# ATTENTION: QCD_Pt_170to300 will be skipped
# ATTENTION: QCD_Pt_1800to2400 will be skipped
# ATTENTION: QCD_Pt_2400to3200 will be skipped
# ATTENTION: QCD_Pt_300to470 will be skipped
# ATTENTION: QCD_Pt_3200toInf will be skipped
# ATTENTION: QCD_Pt_470to600 will be skipped
# ATTENTION: QCD_Pt_600to800 will be skipped
# ATTENTION: QCD_Pt_800to1000 will be skipped
# ATTENTION: ST_s-channel_4f_hadronicDecays will be skipped
# ATTENTION: ST_s-channel_4f_leptonDecays will be skipped
# ATTENTION: ST_t-channel_antitop_4f_InclusiveDecays will be skipped
# ATTENTION: ST_t-channel_top_4f_InclusiveDecays will be skipped
# ATTENTION: ST_tW_antitop_5f_inclusiveDecays will be skipped
# ATTENTION: ST_tW_top_5f_inclusiveDecays will be skipped
# ATTENTION: TTTo2L2Nu will be skipped
# ATTENTION: TTToHadronic will be skipped
# ATTENTION: TTToSemiLeptonic will be skipped
# ATTENTION: WJetsToLNu_HT-100To200 will be skipped
# ATTENTION: WJetsToLNu_HT-1200To2500 will be skipped
# ATTENTION: WJetsToLNu_HT-200To400 will be skipped
# ATTENTION: WJetsToLNu_HT-2500ToInf will be skipped
# ATTENTION: WJetsToLNu_HT-400To600 will be skipped
# ATTENTION: WJetsToLNu_HT-600To800 will be skipped
# ATTENTION: WJetsToLNu_HT-800To1200 will be skipped
# ATTENTION: WJetsToQQ_HT-200to400 will be skipped
# ATTENTION: WJetsToQQ_HT-400to600 will be skipped
# ATTENTION: WJetsToQQ_HT-600to800 will be skipped
# ATTENTION: WJetsToQQ_HT-800toInf will be skipped
# ATTENTION: WW will be skipped
# ATTENTION: WZ will be skipped
# ATTENTION: ZJetsToQQ_HT-200to400 will be skipped
# ATTENTION: ZJetsToQQ_HT-400to600 will be skipped
# ATTENTION: ZJetsToQQ_HT-600to800 will be skipped
# ATTENTION: ZJetsToQQ_HT-800toInf will be skipped
# ATTENTION: ZZ will be skipped
# is data
# is data
# is data
# is data
# is data
# is data
# is data
# is data
# is data
# is data
# sample Data
# Hist(Regular(15, 40, 180, name='var', label='jet softdrop mass [GeV]'), storage=Double()) # Sum: 11326.0 (13880.0 with flow)

# %%
h.view()
# Out:
# array([ 485.,  553.,  767., 1203., 2105., 2085., 1324.,  827.,  607.,
#         439.,  293.,  240.,  156.,  126.,  116.])
