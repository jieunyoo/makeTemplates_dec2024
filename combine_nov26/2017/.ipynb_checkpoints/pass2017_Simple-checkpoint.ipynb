# %%
import argparse
import glob
import json
import logging
import os
import pickle as pkl
import warnings
import hist as hist2
import numpy as np
import pandas as pd
import pyarrow
import yaml
from systematicsPass import get_systematic_dict, sigs
from utils import get_common_sample_name, get_finetuned_score, get_xsecweight
logging.basicConfig(level=logging.INFO)

warnings.filterwarnings("ignore", message="Found duplicate branch ")
pd.set_option("mode.chained_assignment", None)


from jieun import applyTriggerSF_2018, applyTriggerSF_2017, applyTriggerSF_2016, applyTriggerSF_up_2018, applyTriggerSF_up_2017, applyTriggerSF_up_2016, applyTriggerSF_down_2018, applyTriggerSF_down_2017, applyTriggerSF_down_2016 
from jieun import fix_neg_yields, get_templates, mass_binning



CATEGORY = 'pass'

# %%
years = ['2017']

outdir = 'templates'

channels = 'mu','ele'
#channels = ['mu']


with open("simplePass.yaml", "r") as stream:
    config = yaml.safe_load(stream)

if len(years) == 4:
    save_as = "Run2"
else:
    save_as = "_".join(years)

if len(channels) == 1:
    save_as += f"_{channels[0]}_"

os.system(f"mkdir -p {outdir}")

hists = get_templates( years, channels, config["samples"], config["samples_dir"], config["regions_sel"], config["model_path"],)

fix_neg_yields(hists)

#with open(f"{outdir}/hists_templates_{save_as}.pkl", "wb") as fp:
with open(f"{outdir}/hists_templates_{save_as}_pass.pkl", "wb") as fp:
    print('hists', hists)
    pkl.dump(hists, fp)
# Out:
# INFO:root:Processing year 2017 and mu channel
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 123 events
# INFO:root:Applying SR1 selection on 120 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-100To250 samples and should combine them under DYJets
# INFO:root:No parquet file for DYJetsToLL_LHEFilterPtZ-100To250
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-250To400 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 127101 events
# INFO:root:Applying SR1 selection on 124685 events
# INFO:root:Will fill the histograms with the remaining 45 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 41523 events
# INFO:root:Applying SR1 selection on 38849 events
# INFO:root:Will fill the histograms with the remaining 16 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-50To100 samples and should combine them under DYJets
# INFO:root:No parquet file for DYJetsToLL_LHEFilterPtZ-50To100
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-650ToInf samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 73990 events
# INFO:root:Applying SR1 selection on 60825 events
# INFO:root:Will fill the histograms with the remaining 14 events
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Applying fj_mass selection on 5541 events
# INFO:root:Applying SR1 selection on 5416 events
# INFO:root:Will fill the histograms with the remaining 42 events
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Applying fj_mass selection on 21079 events
# INFO:root:Applying SR1 selection on 20839 events
# INFO:root:Will fill the histograms with the remaining 1282 events
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying fj_mass selection on 9907 events
# INFO:root:Applying SR1 selection on 9798 events
# INFO:root:Will fill the histograms with the remaining 606 events
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying fj_mass selection on 11755 events
# INFO:root:Applying SR1 selection on 11648 events
# INFO:root:Will fill the histograms with the remaining 731 events
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Applying fj_mass selection on 20601 events
# INFO:root:Applying SR1 selection on 20398 events
# INFO:root:Will fill the histograms with the remaining 1663 events
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 254 events
# INFO:root:Applying SR1 selection on 235 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 8855 events
# INFO:root:Applying SR1 selection on 8335 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 7741 events
# INFO:root:Applying SR1 selection on 7483 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 18516 events
# INFO:root:Applying SR1 selection on 17843 events
# INFO:root:Will fill the histograms with the remaining 6 events
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 5974 events
# INFO:root:Applying SR1 selection on 5732 events
# INFO:root:Will fill the histograms with the remaining 5 events
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 5850 events
# INFO:root:Applying SR1 selection on 5628 events
# INFO:root:Will fill the histograms with the remaining 4 events
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Applying fj_mass selection on 58042 events
# INFO:root:Applying SR1 selection on 51438 events
# INFO:root:Will fill the histograms with the remaining 535 events
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 205729 events
# INFO:root:Applying SR1 selection on 199278 events
# INFO:root:Will fill the histograms with the remaining 175 events
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 5928 events
# INFO:root:Applying SR1 selection on 5460 events
# INFO:root:Will fill the histograms with the remaining 10 events
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 578643 events
# INFO:root:Applying SR1 selection on 530128 events
# INFO:root:Will fill the histograms with the remaining 451 events
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Applying fj_mass selection on 811 events
# INFO:root:Applying SR1 selection on 802 events
# INFO:root:Will fill the histograms with the remaining 12 events
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 23 events
# INFO:root:Applying SR1 selection on 23 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 124168 events
# INFO:root:Applying SR1 selection on 94436 events
# INFO:root:Will fill the histograms with the remaining 89 events
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 14226 events
# INFO:root:Applying SR1 selection on 14208 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 44949 events
# INFO:root:Applying SR1 selection on 27798 events
# INFO:root:Will fill the histograms with the remaining 10 events
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 30604 events
# INFO:root:Applying SR1 selection on 30410 events
# INFO:root:Will fill the histograms with the remaining 25 events
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 75176 events
# INFO:root:Applying SR1 selection on 72649 events
# INFO:root:Will fill the histograms with the remaining 87 events
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 106627 events
# INFO:root:Applying SR1 selection on 95411 events
# INFO:root:Will fill the histograms with the remaining 107 events
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 816 events
# INFO:root:Applying SR1 selection on 803 events
# INFO:root:Will fill the histograms with the remaining 3 events
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 422 events
# INFO:root:Applying SR1 selection on 411 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 148 events
# INFO:root:Applying SR1 selection on 144 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Processing year 2017 and ele channel
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-0To50 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 196 events
# INFO:root:Applying SR1 selection on 194 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-100To250 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 4978 events
# INFO:root:Applying SR1 selection on 4917 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-250To400 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 321295 events
# INFO:root:Applying SR1 selection on 317012 events
# INFO:root:Will fill the histograms with the remaining 31 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-400To650 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 92260 events
# INFO:root:Applying SR1 selection on 87071 events
# INFO:root:Will fill the histograms with the remaining 5 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-50To100 samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 212 events
# INFO:root:Applying SR1 selection on 209 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Finding DYJetsToLL_LHEFilterPtZ-650ToInf samples and should combine them under DYJets
# INFO:root:Applying fj_mass selection on 125543 events
# INFO:root:Applying SR1 selection on 103669 events
# INFO:root:Will fill the histograms with the remaining 5 events
# INFO:root:Finding GluGluHToWW_Pt-200ToInf_M-125 samples and should combine them under ggF
# INFO:root:Applying fj_mass selection on 3209 events
# INFO:root:Applying SR1 selection on 3131 events
# INFO:root:Will fill the histograms with the remaining 26 events
# INFO:root:Finding GluGluZH_HToWW_M-125_TuneCP5_13TeV-powheg-pythia8 samples and should combine them under ZH
# INFO:root:Applying fj_mass selection on 13312 events
# INFO:root:Applying SR1 selection on 13154 events
# INFO:root:Will fill the histograms with the remaining 640 events
# INFO:root:Finding HWminusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying fj_mass selection on 5352 events
# INFO:root:Applying SR1 selection on 5303 events
# INFO:root:Will fill the histograms with the remaining 319 events
# INFO:root:Finding HWplusJ_HToWW_M-125 samples and should combine them under WH
# INFO:root:Applying fj_mass selection on 6643 events
# INFO:root:Applying SR1 selection on 6569 events
# INFO:root:Will fill the histograms with the remaining 367 events
# INFO:root:Finding HZJ_HToWW_M-125 samples and should combine them under ZH
# INFO:root:Applying fj_mass selection on 12921 events
# INFO:root:Applying SR1 selection on 12798 events
# INFO:root:Will fill the histograms with the remaining 878 events
# INFO:root:Finding ST_s-channel_4f_hadronicDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 21 events
# INFO:root:Applying SR1 selection on 20 events
# INFO:root:Will fill the histograms with the remaining 0 events
# INFO:root:Finding ST_s-channel_4f_leptonDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 5654 events
# INFO:root:Applying SR1 selection on 5332 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Finding ST_t-channel_antitop_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 4206 events
# INFO:root:Applying SR1 selection on 4082 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Finding ST_t-channel_top_4f_InclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 9826 events
# INFO:root:Applying SR1 selection on 9485 events
# INFO:root:Will fill the histograms with the remaining 3 events
# INFO:root:Finding ST_tW_antitop_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 4014 events
# INFO:root:Applying SR1 selection on 3865 events
# INFO:root:Will fill the histograms with the remaining 6 events
# INFO:root:Finding ST_tW_top_5f_inclusiveDecays samples and should combine them under SingleTop
# INFO:root:Applying fj_mass selection on 3938 events
# INFO:root:Applying SR1 selection on 3794 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Finding ttHToNonbb_M125 samples and should combine them under ttH
# INFO:root:Applying fj_mass selection on 34465 events
# INFO:root:Applying SR1 selection on 30579 events
# INFO:root:Will fill the histograms with the remaining 235 events
# INFO:root:Finding TTTo2L2Nu samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 131224 events
# INFO:root:Applying SR1 selection on 127120 events
# INFO:root:Will fill the histograms with the remaining 79 events
# INFO:root:Finding TTToHadronic samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 1043 events
# INFO:root:Applying SR1 selection on 966 events
# INFO:root:Will fill the histograms with the remaining 5 events
# INFO:root:Finding TTToSemiLeptonic samples and should combine them under TTbar
# INFO:root:Applying fj_mass selection on 380093 events
# INFO:root:Applying SR1 selection on 348210 events
# INFO:root:Will fill the histograms with the remaining 290 events
# INFO:root:Finding VBFHToWWToAny_M-125_TuneCP5_withDipoleRecoil samples and should combine them under VBF
# INFO:root:Applying fj_mass selection on 479 events
# INFO:root:Applying SR1 selection on 469 events
# INFO:root:Will fill the histograms with the remaining 6 events
# INFO:root:Finding WJetsToLNu_HT-100To200 samples and should combine them under WJetsLNu
# INFO:root:Finding WJetsToLNu_HT-1200To2500 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 78394 events
# INFO:root:Applying SR1 selection on 59555 events
# INFO:root:Will fill the histograms with the remaining 37 events
# INFO:root:Finding WJetsToLNu_HT-200To400 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 10769 events
# INFO:root:Applying SR1 selection on 10753 events
# INFO:root:Will fill the histograms with the remaining 1 events
# INFO:root:Finding WJetsToLNu_HT-2500ToInf samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 27231 events
# INFO:root:Applying SR1 selection on 16820 events
# INFO:root:Will fill the histograms with the remaining 3 events
# INFO:root:Finding WJetsToLNu_HT-400To600 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 20708 events
# INFO:root:Applying SR1 selection on 20555 events
# INFO:root:Will fill the histograms with the remaining 16 events
# INFO:root:Finding WJetsToLNu_HT-600To800 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 49167 events
# INFO:root:Applying SR1 selection on 47396 events
# INFO:root:Will fill the histograms with the remaining 51 events
# INFO:root:Finding WJetsToLNu_HT-800To1200 samples and should combine them under WJetsLNu
# INFO:root:Applying fj_mass selection on 68793 events
# INFO:root:Applying SR1 selection on 61414 events
# INFO:root:Will fill the histograms with the remaining 62 events
# INFO:root:Finding WW samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 602 events
# INFO:root:Applying SR1 selection on 589 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Finding WZ samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 449 events
# INFO:root:Applying SR1 selection on 435 events
# INFO:root:Will fill the histograms with the remaining 2 events
# INFO:root:Finding ZZ samples and should combine them under Diboson
# INFO:root:Applying fj_mass selection on 239 events
# INFO:root:Applying SR1 selection on 236 events
# INFO:root:Will fill the histograms with the remaining 0 events
# hists Hist(
#   StrCategory(['DYJets', 'ggF', 'ZH', 'WH', 'SingleTop', 'ttH', 'TTbar', 'VBF', 'WJetsLNu', 'Diboson'], growth=True, name='Sample'),
#   StrCategory(['pass_nominal', 'pass_weight_trigger_up', 'pass_weight_trigger_down', 'pass_weight_pdf_acceptance_DYJets_up', 'pass_weight_pdf_acceptance_DYJets_down', 'pass_weight_qcd_scale_DYJets_up', 'pass_weight_qcd_scale_DYJets_down', 'pass_top_reweighting_up', 'pass_top_reweighting_down', 'pass_weight_pileup_id_up', 'pass_weight_pileup_id_down', 'pass_weight_d1K_NLO_up', 'pass_weight_d1K_NLO_down', 'pass_weight_d2K_NLO_up', 'pass_weight_d2K_NLO_down', 'pass_weight_d3K_NLO_up', 'pass_weight_d3K_NLO_down', 'pass_weight_d1kappa_EW_up', 'pass_weight_d1kappa_EW_down', 'pass_weight_W_d2kappa_EW_up', 'pass_weight_W_d2kappa_EW_down', 'pass_weight_W_d3kappa_EW_up', 'pass_weight_W_d3kappa_EW_down', 'pass_weight_Z_d2kappa_EW_up', 'pass_weight_Z_d2kappa_EW_down', 'pass_weight_Z_d3kappa_EW_up', 'pass_weight_Z_d3kappa_EW_down', 'pass_weight_ele_id_up', 'pass_weight_ele_id_down', 'pass_weight_ele_reco_up', 'pass_weight_ele_reco_down', 'pass_weight_mu_isolation_up', 'pass_weight_mu_isolation_down', 'pass_weight_mu_id_up', 'pass_weight_mu_id_down', 'pass_weight_mu_trigger_iso_up', 'pass_weight_mu_trigger_iso_down', 'pass_weight_mu_trigger_noniso_up', 'pass_weight_mu_trigger_noniso_down', 'pass_weight_pileup_up', 'pass_weight_pileup_down', 'pass_weight_L1Prefiring_up', 'pass_weight_L1Prefiring_down', 'pass_weight_PSFSR_DYJets_up', 'pass_weight_PSFSR_DYJets_down', 'pass_weight_PSISR_DYJets_up', 'pass_weight_PSISR_DYJets_down', 'pass_weight_btagSFlightCorrelated_up', 'pass_weight_btagSFlightCorrelated_down', 'pass_weight_btagSFbcCorrelated_up', 'pass_weight_btagSFbcCorrelated_down', 'pass_weight_btagSFlight_up', 'pass_weight_btagSFlight_down', 'pass_weight_btagSFbc_up', 'pass_weight_btagSFbc_down', 'pass_JES_FlavorQCD_up', 'pass_JES_FlavorQCD_down', 'pass_JES_RelativeBal_up', 'pass_JES_RelativeBal_down', 'pass_JES_HF_up', 'pass_JES_HF_down', 'pass_JES_BBEC1_up', 'pass_JES_BBEC1_down', 'pass_JES_EC2_up', 'pass_JES_EC2_down', 'pass_JES_Absolute_up', 'pass_JES_Absolute_down', 'pass_JES_BBEC1_year_up', 'pass_JES_BBEC1_year_down', 'pass_JES_RelativeSample_year_up', 'pass_JES_RelativeSample_year_down', 'pass_JES_EC2_year_up', 'pass_JES_EC2_year_down', 'pass_JES_HF_year_up', 'pass_JES_HF_year_down', 'pass_JES_Absolute_year_up', 'pass_JES_Absolute_year_down', 'pass_JER_year_up', 'pass_JER_year_down', 'pass_UES_up', 'pass_UES_down', 'pass_weight_pdf_acceptance_ggF_up', 'pass_weight_pdf_acceptance_ggF_down', 'pass_weight_qcd_scale_ggF_up', 'pass_weight_qcd_scale_ggF_down', 'pass_weight_PSFSR_ggF_up', 'pass_weight_PSFSR_ggF_down', 'pass_weight_PSISR_ggF_up', 'pass_weight_PSISR_ggF_down', 'pass_weight_pdf_acceptance_ZH_up', 'pass_weight_pdf_acceptance_ZH_down', 'pass_weight_qcd_scale_ZH_up', 'pass_weight_qcd_scale_ZH_down', 'pass_weight_PSFSR_ZH_up', 'pass_weight_PSFSR_ZH_down', 'pass_weight_PSISR_ZH_up', 'pass_weight_PSISR_ZH_down', 'pass_weight_pdf_acceptance_WH_up', 'pass_weight_pdf_acceptance_WH_down', 'pass_weight_qcd_scale_WH_up', 'pass_weight_qcd_scale_WH_down', 'pass_weight_PSFSR_WH_up', 'pass_weight_PSFSR_WH_down', 'pass_weight_PSISR_WH_up', 'pass_weight_PSISR_WH_down', 'pass_weight_pdf_acceptance_SingleTop_up', 'pass_weight_pdf_acceptance_SingleTop_down', 'pass_weight_qcd_scale_SingleTop_up', 'pass_weight_qcd_scale_SingleTop_down', 'pass_weight_PSFSR_SingleTop_up', 'pass_weight_PSFSR_SingleTop_down', 'pass_weight_PSISR_SingleTop_up', 'pass_weight_PSISR_SingleTop_down', 'pass_weight_pdf_acceptance_ttH_up', 'pass_weight_pdf_acceptance_ttH_down', 'pass_weight_qcd_scale_ttH_up', 'pass_weight_qcd_scale_ttH_down', 'pass_weight_PSFSR_ttH_up', 'pass_weight_PSFSR_ttH_down', 'pass_weight_PSISR_ttH_up', 'pass_weight_PSISR_ttH_down', 'pass_weight_pdf_acceptance_TTbar_up', 'pass_weight_pdf_acceptance_TTbar_down', 'pass_weight_qcd_scale_TTbar_up', 'pass_weight_qcd_scale_TTbar_down', 'pass_weight_PSFSR_TTbar_up', 'pass_weight_PSFSR_TTbar_down', 'pass_weight_PSISR_TTbar_up', 'pass_weight_PSISR_TTbar_down', 'pass_weight_pdf_acceptance_VBF_up', 'pass_weight_pdf ...
#   StrCategory(['SR1'], growth=True, name='Region'),
#   Variable([40, 70, 110, 140, 180], name='mass_observable', label='V reconstructed mass [GeV]'),
#   storage=Weight()) # Sum: WeightedSum(value=12025, variance=2030.34) (WeightedSum(value=12174.4, variance=2077.4) with flow)
